# %%
# !jupyter nbconvert --output-dir='../docs' --to html 01_ITRP_datasets_description.ipynb
# Out:
# [NbConvertApp] Converting notebook 01_ITRP_datasets_description.ipynb to html
# [NbConvertApp] Writing 275982 bytes to ../docs/01_ITRP_datasets_description.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 00_prepare_data.ipynb
# Out:
# [NbConvertApp] Converting notebook 00_prepare_data.ipynb to html
# [NbConvertApp] Writing 311661 bytes to ../docs/00_prepare_data.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 02_compass_finetuning.ipynb
# Out:
# [NbConvertApp] Converting notebook 02_compass_finetuning.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 2 image(s).
# [NbConvertApp] Writing 438436 bytes to ../docs/02_compass_finetuning.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 03_compass_prediction.ipynb
# Out:
# [NbConvertApp] Converting notebook 03_compass_prediction.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 347826 bytes to ../docs/03_compass_prediction.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 04_logstic_regression.ipynb
# Out:
# [NbConvertApp] Converting notebook 04_logstic_regression.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 347073 bytes to ../docs/04_logstic_regression.html
