# %%
# !jupyter nbconvert --output-dir='../docs' --to html 00_prepare_data.ipynb
# Out:
# [NbConvertApp] Converting notebook 00_prepare_data.ipynb to html
# [NbConvertApp] Writing 311661 bytes to ../docs/00_prepare_data.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 01_TCGA_ITRP_datasets.ipynb
# Out:
# [NbConvertApp] Converting notebook 01_TCGA_ITRP_datasets.ipynb to html
# [NbConvertApp] Writing 281500 bytes to ../docs/01_TCGA_ITRP_datasets.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 02_compass_pretrain.ipynb
# Out:
# [NbConvertApp] Converting notebook 02_compass_pretrain.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 355428 bytes to ../docs/02_compass_pretrain.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 03_compass_concepts.ipynb
# Out:
# [NbConvertApp] Converting notebook 03_compass_concepts.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 4 image(s).
# [NbConvertApp] Writing 2607554 bytes to ../docs/03_compass_concepts.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 04_compass_finetuning.ipynb
# Out:
# [NbConvertApp] Converting notebook 04_compass_finetuning.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 2 image(s).
# [NbConvertApp] Writing 441373 bytes to ../docs/04_compass_finetuning.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 05_compass_prediction.ipynb
# Out:
# [NbConvertApp] Converting notebook 05_compass_prediction.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 351063 bytes to ../docs/05_compass_prediction.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 06_compass_extraction.ipynb
# Out:
# [NbConvertApp] Converting notebook 06_compass_extraction.ipynb to html
# [NbConvertApp] Writing 315069 bytes to ../docs/06_compass_extraction.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 07_compass_CRMap.ipynb
# Out:
# [NbConvertApp] Converting notebook 07_compass_CRMap.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 2 image(s).
# [NbConvertApp] Writing 2521357 bytes to ../docs/07_compass_CRMap.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 08_compass_LGR.ipynb
# Out:
# [NbConvertApp] Converting notebook 08_compass_LGR.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 347385 bytes to ../docs/08_compass_LGR.html

# %%
# !jupyter nbconvert --output-dir='../docs' --to html 09_compass_CoxPH.ipynb
# Out:
# [NbConvertApp] Converting notebook 09_compass_CoxPH.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 2 image(s).
# [NbConvertApp] Writing 465752 bytes to ../docs/09_compass_CoxPH.html

# %%
import sys
sys.path.insert(0, '/media/ssd/Research/aliyun_sync/aliyun_sync/COMPASS/')
